# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.eb.dk"
r = requests.get(url)
r.headers
# Out:
# {'X-Cache': 'HIT', 'Transfer-Encoding': 'chunked', 'Content-Language': 'da-DK', 'Age': '105', 'X-EB-Device': 'desktop', 'X-Cache-Host': 'cerberus168', 'grace': 'none', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 30 Jan 2017 14:19:48 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'X-Varnish': '238074169 236896991', 'Server': 'Apache-Coyote/1.1', 'Vary': 'Accept-Encoding', 'Connection': 'keep-alive', 'Via': '1.1 varnish-v4', 'X-Backend': 'escenicengine4(172.24.20.131)'}

# %%
for key in r.headers.keys():
    print (key)
# Out:
# X-Cache
# Content-Type
# Via
# Content-Language
# Accept-Ranges
# grace
# Transfer-Encoding
# Server
# X-EB-Device
# Age
# X-Backend
# X-Varnish
# Connection
# X-Cache-Host
# Date
# Vary

# %%
print (r.headers['Content-Language'])
print (r.headers['Content-Type'])
# Out:
# da-DK
# text/html;charset=UTF-8

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html itemscope itemtype="http://schema.org/Article">\n<head>\n    <!-- tv timestamp -->\n<script type="text/javascript">\n        var le_tv_timestamp_0 = new Date().getTime();\n    </script>\n<title>Nyheder, sport og underholdning – Ekstra Bladet</title>\n<meta http-equiv="X-UA-Compatible" content="IE=EDGE" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta name="google-site-verification" content="oxh_akV_RyJauxLiESflzfirJqdEbd7UpwEY7QlvTGI" />\n\n<meta name="robots" content="noarchive" />\n\n<meta name="robots" content="index, follow" />\n    <meta property="fb:app_id" content="123629220366" />\n<!-- section meta -->\n        <meta name="description" content="" />\n<meta property="og:type" content="article" />\n    <meta property="og:title" content="Forside" />\n\n    <meta property="og:image" content="http://ebimg.dk/ux/data/social/logo-xl.png" />\n\n    <meta property="og:url" content="http://ekstrabladet.dk/" />\n    <meta name="tw
# ...
